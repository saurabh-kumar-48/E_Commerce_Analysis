# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\ASUS\Downloads\Ecommerce_Delivery_Analytics_New.csv")

# %%
df.head()
# Out:
#     Order ID Customer ID Platform Order Date & Time  Delivery Time (Minutes)  \
# 0  ORD000001    CUST2824  JioMart           19:29.5                       30
# 1  ORD000002    CUST1409  Blinkit           54:29.5                       16
# 2  ORD000003    CUST5506  JioMart           21:29.5                       25
# 3  ORD000004    CUST5012  JioMart           19:29.5                       42
# 4  ORD000005    CUST4657  Blinkit           49:29.5                       30
#
#       Product Category  Order Value (INR)              Customer Feedback  \
# 0  Fruits & Vegetables                382  Fast delivery, great service!
# 1                Dairy                279            Quick and reliable!
# 2            Beverages                599      Items missing from order.
# 3            Beverages                946      Items missing from order.
# 4            Beverages                334  Fast delivery, great service!
#
#    Service Rating Delivery Delay Refund Requested
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Order ID                 100000 non-null  object
#  1   Customer ID              100000 non-null  object
#  2   Platform                 100000 non-null  object
#  3   Order Date & Time        100000 non-null  object
#  4   Delivery Time (Minutes)  100000 non-null  int64
#  5   Product Category         100000 non-null  object
#  6   Order Value (INR)        100000 non-null  int64
#  7   Customer Feedback        100000 non-null  object
#  8   Service Rating           100000 non-null  int64
#  9   Delivery Delay           100000 non-null  object
#  10  Refund Requested         100000 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 8.4+ MB

# %%
Df.describe()
# Out:
#        Delivery Time (Minutes)  Order Value (INR)  Service Rating
# count            100000.000000      100000.000000   100000.000000
# mean                 29.536140         590.994400        3.240790
# std                   9.958933         417.409058        1.575962
# min                   5.000000          50.000000        1.000000
# 25%                  23.000000         283.000000        2.000000
# 50%                  30.000000         481.000000        3.000000
# 75%                  36.000000         770.000000        5.000000
# max                  76.000000        2000.000000        5.000000

# %%
df.drop('Order Date & Time', axis=1, inplace=True ,errors='ignore')

# %%
df.head()
# Out:
#     Order ID Customer ID Platform  Delivery Time (Minutes)  \
# 0  ORD000001    CUST2824  JioMart                       30
# 1  ORD000002    CUST1409  Blinkit                       16
# 2  ORD000003    CUST5506  JioMart                       25
# 3  ORD000004    CUST5012  JioMart                       42
# 4  ORD000005    CUST4657  Blinkit                       30
#
#       Product Category  Order Value (INR)              Customer Feedback  \
# 0  Fruits & Vegetables                382  Fast delivery, great service!
# 1                Dairy                279            Quick and reliable!
# 2            Beverages                599      Items missing from order.
# 3            Beverages                946      Items missing from order.
# 4            Beverages                334  Fast delivery, great service!
#
#    Service Rating Delivery Delay Refund Requested
# 0               5             No               No
# 1               5             No               No
# ...

# %%
import matplotlib.pyplot as plt

# Group revenue by product category
category_sales = df.groupby('Product Category')['Order Value (INR)'].sum().sort_values(ascending=False)

# Plot bar chart
plt.figure(figsize=(10, 6))
category_sales.plot(kind='bar', color='skyblue')

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue (INR)")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))
category_sales.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title("Revenue Share by Product Category")
plt.ylabel("")  # Hides y-axis label
plt.show()

# %%
# Visualizing the distribution of delivery times
plt.figure(figsize=(10, 5))
sns.histplot(Data["Delivery Time (Minutes)"], bins=30, kde=True, color='blue')
plt.title("Distribution of Delivery Time", fontsize=14)
plt.xlabel("Delivery Time (Minutes)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
revenue_by_platform = Data.groupby('Platform')['Order Value (INR)'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=revenue_by_platform.index, y=revenue_by_platform.values, palette="coolwarm")
plt.title("Total Revenue by Platform")
plt.xlabel("Platform")
plt.ylabel("Total Revenue (INR)")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16972\998284256.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenue_by_platform.index, y=revenue_by_platform.values, palette="coolwarm")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Clean column names again, just to be sure
Data.columns = Data.columns.str.strip()

# Group total revenue by product category
product_revenue = Data.groupby('Product Category')['Order Value (INR)'].sum().sort_values(ascending=False)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x=product_revenue.values, y=product_revenue.index, palette="coolwarm")

plt.title("Total Revenue by Product Category")
plt.xlabel("Total Revenue (INR)")
plt.ylabel("Product Category")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16972\3730180852.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_revenue.values, y=product_revenue.index, palette="coolwarm")

# %%
#Total Revenue Generated
total_revenue = Data['Order Value (INR)'].sum()
print(f"Total Revenue Generated: ₹{total_revenue:,}")
# Out:
# Total Revenue Generated: ₹59,099,440

# %%
#Total Orders
total_orders = len(Data)
print(f"Total Orders: {total_orders:,}")
# Out:
# Total Orders: 100,000

# %%
#Total orders across plateforms
orders_by_platform = df['Platform'].value_counts()
print(orders_by_platform)
# Out:
# Platform
# Swiggy Instamart    33449
# Blinkit             33424
# JioMart             33127
# Name: count, dtype: int64

# %%
#Total refunded orders
df['Refund Requested'] = df['Refund Requested'].str.strip()
total_refunds = df[df['Refund Requested'] == 'Yes'].shape[0]
print(f"Total Refunded Orders: {total_refunds:,}")
# Out:
# Total Refunded Orders: 45,819

# %%
#Late order delivered
late_orders = df[df['Delivery Delay'] == 'Yes'].shape[0]
print(f"Total Orders Delivered Late: {late_orders:,}")
# Out:
# Total Orders Delivered Late: 13,672

# %%
orders_by_platform = df['Platform'].value_counts()
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x=orders_by_platform.index, y=orders_by_platform.values, palette='Set2')

plt.title("Total Orders by Platform")
plt.xlabel("Platform")
plt.ylabel("Number of Orders")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16972\1049366469.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=orders_by_platform.index, y=orders_by_platform.values, palette='Set2')
